# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))  # Go up one directory

from llm_provider import LLM_provider
llm=LLM_provider()

# %%
embedding = llm.embed_query("Hello")

# %%
len(embedding)
# Out:
# 3072

# %%
from langchain_community.document_loaders import TextLoader,DirectoryLoader,PyPDFLoader
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# loader=DirectoryLoader("../data2",glob="./*.txt",loader_cls=TextLoader)
file_path="../docs//BRD.pdf"
loader = PyPDFLoader(file_path)

# %%
docs=loader.load()
docs
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content="Business Requirements Document (BRD) – Savings Account Opening \nProduct: Savings Account | Region: India | Created on: 3 Sept 2025 \n \n1. Introduction \nThis document specifies the business requirements for a fully digital, Agentic AI–enabled \nSavings Account opening journey. The objective is to capture, validate, and process \ncustomer information with high data quality, seamless user experience, and compliance \nwith KYC/AML and bank policies. \n2. Scope \nIn Scope: \n• End-to-end digital onboarding flow for Savings Account applicants \n• Field-level validations, real-time error handling, and exception workflow \n• Agentic AI assistance for data extraction, auto-fill, and proactive checks \n• Document capture, OCR, and verification \n• ETB/NTB journeys \n• DIY/assisted journeys \nOut of Scope: \n• Downstream debit card/courier logistics  \n• Non-savings products \n3. Eligibility Criteria \n• Applicant's age/DOB must satisfy bank policy; DOB must be a valid past date. \n• Residents and non-residents are eligible as per KYC and product policy; residency \nstatus must be captured accurately. \n• Nationality/citizenship must be declared and should not match any \nrestricted/sanctions list. \n• Applicants must pass PEP/sanctions screening in line with AML requirements. \n• Valid KYC documents (identity and address proof) must be provided per regulatory \nnorms. \n• Both salaried and self-employed applicants are supported; employment/occupation \ndetails must be declared."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='4. Business Rules \nThe savings account opening process applies to both existing bank customers (ETB) and new-to-\nbank (NTB) customers, supporting individual, joint, and salary account types for residents and \nnon-residents. The system must accommodate salaried employees, self-employed individuals, \nprofessionals, and other occupation categories, with special provisions for differently abled \napplicants requiring assistance. For DIY or assisted journeys, the user should be able to upload \nmultiple documents and use multi-prompts as inputs. The only difference in DIY and Assisted \njourneys would be identification of user persona : customer vs Branch staff. The remaining \njourney remains the same. \nAll applicants must provide their full legal name with first name mandatory for all applicants, \nmiddle name optional, and last name mandatory for all applicants - all in valid alphabetic text \nformat. The form date is auto-captured by the system in DD/MM/YYYY format. Applicants must \nselect a valid title (Mr., Mrs., Ms., Dr., etc.) from the predefined list.  \nContact information requirements are strict: a valid 10-digit mobile number in numeric format is \nmandatory, while residential phone number (if provided) must be in valid numeric format. Email \naddresses must be in standard format. If email address is not available, then the applicant has to \nsubmit a declaration as per Annexure 1 \nWith the mobile number, the system should check if the mobile number exists in CBS and \nwhether the customer is an existing to bank customer. If the mobile number is found, the \ncustomer can be asked to input PAN # or Account # to do a unique match \nThe applicant has to choose the type of account & purpose.  \nFor identity verification, NTB applicants must provide their PAN card and Aadhar card.  \nFor ETB, the system first needs to check if re-KYC is due. If re-KYC is due, ask for Aadhar Card and \nPAN Card.  \nAcross applicants, If Aadhar card is not available, they should share another officially valid \ndocument (OVD), namely,  \nDriving Licence (Yes/No) \nVoter ID (Yes/No) \nPassport (Yes/No) \nNREGA (Yes/No) \nLetter from National Population Register (Yes/No) \n \nThey should also submit other OVDs in case  \n• Mobile number of the applicant is not linked to Aadhar'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='• Any discrepancy in other details on Aadhar. Example, name as per Aadhar is John Joshua \nDallas but the customer wants to use John Dallas, then he will have to use another OVD \nThe corresponding document number must be provided in valid alphanumeric format matching \nthe selected OVD type.  \n• For Aadhaar, a valid 12-digit number is required \n• for PAN, a valid 10-character alphanumeric number \n• for Passport,  \no a valid passport number in correct format \no Place of issue \no Date of issue \no Date of expiry \n• For Driving License \no valid issue date \no place of issue must be provided in valid text format \no valid driving license number \n• If NREGA is selected, a valid NREGA card number must be provided; if NPR letter is \nselected, a valid NPR reference number is required. \nDate of birth must be provided in DD/MM/YYYY format with validation ensuring the applicant is \nat least 18 years old (except for minors with guardians), and gender must be selected from \nMale, Female, or Other options. Name, Photo, Date of Birth and Gender must be extracted from \nAadhar card or PAN card. Marital status (Single, Married, Divorced, Widowed) is optional. For an \nETB customer, these details can be extracted from CBS. \nFather’s/Spouse first name with last name also mandatory, along with permanent address must \nbe extracted from PAN and Aadhar card. For an ETB customer, these details can be extracted \nfrom CBS. \nThe pin code of current address should be checked for cybercrime hotspots - Individual cust ids \nwith mentioned 3457 pin codes identified as Cyber hotspots in communication (mailing) address \nand the age of the customer is 18 - 25 years are classified with High Risk. Customers with \noccupation “Salaried” and STAFF = Y need to be excluded from this logic. If the customer \naddress belongs to this criteria, then Enhanced due diligence as per Annexure 2 will kick in \nOnce the documents are uploaded, there needs to be checks and validations \n1. Forgery check – whether the document is tampered \n2. AML validations using external APIs \n3. Fraud checks using internal APIs \n4. Consistency check across documents'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content="Occupation details vary by applicant type. Salaried individuals must provide their \norganization/employer name, designation/profession in valid text format. The number of years \nemployed must be a valid non-negative numeric value. Self-employed applicants must provide a \nvalid description of their business nature in descriptive text. All applicants must select their \nsource of income from the predefined list (Salary, Business, Agriculture, etc.) and provide gross \nannual income and net monthly income in valid numeric format. Source of funds or wealth must \nbe declared and the values can be \n• Salary  \n• Business Income  \n• Parents/Spouse/Siblings  \n• Personal Saving  \n• Rent/interest  \n• Agriculture  \n• Investments  \n• Retirement Benefits  \n \nBank employees must declare their status and provide their employer bank name, branch, \noffice, employee ID or PF number, and current designation. All applicants must declare whether \nthey're related to bank staff or directors, and if yes, must provide the full name of the related \nperson. \nThe system should be able to recommend a product to the applicant basis the eligibility criteria \nas per attached product scheme, also captured in the table below \nProduct%20Schemes.\nxlsx\n \nSl. \nNo. Scheme Account \nType Eligibility Age Gend\ner AMB \n1 Bespoke Savings \nAccount Savings Resident Individual Age>18 M/F Rs. 2 lakhs \n2 Celesta Resident Savings \nAMB of ₹10 Lakhs in Celesta Savings \nAccount \nAMB of ₹10 Lakhs across all savings \naccounts \nSalary credit >= ₹2 Lakhs \nAMB of ₹5 Lakhs across all savings \naccount + TD of ₹25 Lakhs \nTRV of ₹1 Crore \n>18 M/F Rs.100000\n0 \n3 Club Savings Account Savings Resident Individuals of Metro Branches  >18 M/F Rs.5000 \n4 Delite Savings Account Savings Resident Individuals of Semi-urban/Urban \nBranches >18 M/F RS.3000 \n5 Fed Excel Savings \nAccount Savings \nProfessionals/Promoters of business/ \nRegistered member of JCI, FICCI AND \nChamber of Commerce \n>18 M/F Rs. 10,000"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='6 Fed Power Plus Savings Resident Individuals >18 M/F Rs.25000 \n7 Fed Smart Savings Resident Individuals >18 M/F Rs.100000 \n8 Fed First Savings Resident Individuals/Minors \nAge: 1 \nday to < \n18 years \nM/F Rs.1000 \n9 Imperio Savings \nAccount Savings Sal >= 1L >18 M/F Rs.200000 \n10 Mahila Mitra Plus Savings Resident Individuals/Female >18 F \nMetro/Ur\nban \nBranch – \nRs.10,000 \nSemi \nUrban \nBranch – \nRs.7,500 \nRural \nBranch – \nRs.5,000 \n11 Pride Savings Account Savings Resident Individuals/ Non-Individuals of \nRural Branches \n M/F Rs.2000 \n12 SB Plus Savings Resident Individuals >18 M/F Rs.5000 \n17 Esteem Savings \nAccount Savings Resident Indian Citizens 55 & \nabove M/F Rs.50,000 \n13 Stellar Savings Account Savings Resident Individuals >18 M/F Rs. 10,000 \n14 Yuvamitra - Students Savings Resident Individuals + Students 18-25 M/F Nil \n15 Fed Salary Premium Savings Resident Individuals/ Salary >30000 >18 M/F nil \n Fed Classic Eazy Savings Resident Individuals/ Salary <10000 >18 M/F Nil \n16 Fed Salary Savings Resident Individuals/ Salary 10000-30000 >18 M/F nil \n18 GovEarn Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.25,000 >18 M/F Nil \n19 GovEarn Prime Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.75,000 >18 M/F Nil \n20 Current Plus Current Resident Individuals >18 M/F Rs. 10,000 \n21 Fed Prime Current Resident Individuals >18 M/F Rs.25Lakh \n22 Fed Trade Current Resident Individuals >18 M/F Rs.25,000 \n23 Fed Trade 50 Current Resident Individuals >18 M/F Rs.50,000 \n24 Fed Trade Plus Current Resident Individuals >18 M/F Rs.100000 \n25 Fed Vanijya Current Resident Individuals >18 M/F Rs.500000 \n26 Fed Vanijya Plus Current Resident Individuals >18 M/F Rs. 10 \nlakh \n27 Freedom Current Current Resident Individuals >18 M/F Rs.5000 \n28 Sweep Plus Current \nAccount Current Resident Individuals >18 M/F Rs.300000 \n \nFor joint accounts, if the primary applicant says there will be a joint-account holder, the agent \nshould ask for the co-applicant’s mobile number and PAN/Aadhar, generate a link and send a \nlink to the co-applicant to fill in their details which would be same fields required as that of \nprimary applicant.  \nValue added services \n The applicant should confirm the value added services they want to opt out of'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 5, 'page_label': '6'}, page_content='• Passbook  \n• Mobile alerts  \n• Email Statement  \n• Physical Statement  \n• Mobile Banking (FedMobile)  \n• Internet banking (FedNet)  \n• AePS \n• Aadhaar Seeding  \n \n• Cheque book required  \n• Debit card  \n• Customized Debit Card Type of Card (list of all cards eligible for the respective \nscheme shall be listed.)  \n• Celesta & Imperio cards are only issued one per Cust ID even if the customer opens \nmultiple celesta/Imperio accounts.  \nNomination is optional with specific requirements \ni No  \nIf No, User should readout the following to customer.  \nI/ We have been explained by the bank official that the nomination facility is available. I/ We \nalso understood that this facility will enable the Bank to make the settlement to the nominee, \nhassle free and without insisting any legal documents, in case of any unfortunate event of death. \nAfter considering Bank’s request, I/we have decided not to provide the nomination and demand \nthat the Bank should open my/our account/s without nomination.  \nYes  \nIf Yes, User need to enter the following  \ni Enter Customer ID, if Nominee is existing customer of Federal bank  \nii Name of the nominee \niii Address (If customer ID not entered, An option select the address of the \ndepositor/s shall be provided)  \niv Relationship with the depositor'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 6, 'page_label': '7'}, page_content='v Age. If Age is below 18, Collect following details  \n• Date of birth  \n• Name of the Guardian/lawfully  \n• Address  \n• Age  \nSystem to auto populate values in the field ii, iii, & v if customer ID is entered in step i above.  \nAll applications must undergo rigorous validation: mandatory fields must be complete with \nproper data types, signatures must be present in digital, e-sign, or wet-ink format, declarations \nmust be confirmed, and eligibility checks (age, income, risk profile) must be passed. The system \nmust perform duplicate application checks, sanction list screening, and real-time eligibility \nchecks based on credit score and risk policy. All mandatory fields must be validated before \nsubmission. \nAll declarations, as applicable should be accepted by the customer \nSystem requirements are comprehensive: unique application numbers and tracking IDs must be \ngenerated for each submission; channel of application (Branch, Online, Mobile) must be \nrecorded; session timeout must occur after 15 minutes of inactivity; all sensitive data must be \nencrypted during transmission and storage; and compliance with data privacy regulations \n(GDPR, local laws) is mandatory. The system must integrate with central KYC registry, credit \nbureau, Aadhaar, PAN, MCA, and GSTN for real-time validation. OCR extraction from uploaded \ndocuments must be supported with data validation against user input, and manual override \nmust require justification. \nAn account opening form in standard template shall be created by auto populating the data \ncaptured during the CIF creation and account opening journey. This template shall contain all \nthe terms and conditions. Our standard AOF template to be used.  \nCustomer ID creation form in standard template shall be generated and displayed in the screen. \nUser shall be given two options “Confirm & Proceed” and “Modify”(modification would not be \nallowed for KYC details). In case of Confirm and proceed, user shall be taken to next step for \nsigning the AOF. If user click on Modify, they can update any information  \nOption 1: E Sign (Available only for Aadhaar customers).  \nAadhar biometric based e signing  The auto populated account opening form is displayed in the \nscreen, and customer reviews the same and does the biometric based e-sign using fingerprint \n(fingerprint sensor connected to the device) or face authorization (through the camera attached \nwith the device).  \nIn case the customer finds some information, which needs to be amended, the changes can be \nmade by user and trigger the e-signing process again.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 7, 'page_label': '8'}, page_content='Aadhar OTP based e sign  \nThe auto populated account opening form along with the Name, DOB, mobile number and email \nID (if available) shall be passed to e sign API. (Since there can be time gap between this step and \nnext step, system shall have provision to save the application and resume the process after \ngetting esign completion confirmation)  \nCustomer will receive the notification in the given mobile number and email ID (if available).  \nCustomer to open the link, review the document and confirm the details and proceed with \nAadhaar based e signing process.  \nIn case the customer finds some information, which needs to be amended, the changes can be \nmade by user and resend the same to the customer again for e signing.  \nOption 2: Digital signature  \nThe auto populated account opening form is sent to the customer mobile number and email ID  \nCustomer reviews the document, sign it using the digital signature and send it back to the bank \n(Since there can be time gap between this step  \ni resume the process after getting the digitally signed application back)  \nii User to upload the digitally signed document and click on Verify Digital Signature \nbutton to confirm the validity of the digital signature  \niii System to use eMudra APIs to verify the digital signature  \niv User shall be allowed to proceed if the digital signature is valid  \nv If digital signature is not valid, user shall advice user to redo the digital signature or fall \nback onto any other option to get the document authorized  \nOption 3: Wet signature in account opening form (Incase the eSign/Digital signature is not \npossible)  \nSystem shall give an option to generate One pager summary as per the template  \nANNEXURE%201-%2\n0One%20pager%20-%20V1.docx\n \nUser can either print the document or manually prepare the document in the standard template \nand get it signed or thumb impression'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 8, 'page_label': '9'}, page_content="User to upload/capture the signed document in the application If customer has provided email \nid in AOF 1 Pager would be wet signed by customer. User (Federal Branch Official) will capture \nimage of the document in AO Portal. User will submit the AOF for processing, this step will also \ntrigger email to customer a copy of entire AOF along with 1 pager signed by customer (this will 1 \nconsolidated document in PDF)  \n1 pager original to be retained at branch  \n2 Communication content in the email to be provided by Compliance team  \nThis customer authorization process shall be applicable for all applicant of the particular \naccount. There may be multiple applicants for a single product, so there shall system validations \nand capability to capture all the customer authorization. User shall be able to proceed further \nonly after the authorization by all customer is received.  \nProcess for 1 pager wet signature:  \nIf e-sign and digital signature of AOF is not possible , Obtaining customer's signature on 1 pager \nin AOF  \n• If Customer does not have email id, 1 Pager would be wet signed by customer  \n• User (Federal Branch Official) will capture image of the document in AO Portal  \n• A link would be sent to customer in SMS  \n• Link would contain AOF+1 pager(this will 1 consolidated document in PDF)  \n• Clicking the link would open the document  \n• Customer will read and review the document and agree to the content  \n• At the end of documents placeholder would be provided for OTP sent by Federal bank \nthrough SMS on verified mobile  \n• After entering OTP , Customer will submit and message would be received in AO Portal \nthrough backend. If OTP is matched, user will get the tab to proceed  \n• User will submit AOF +1 Pager for processing  \n• 1 pager original to be retained at branch  \nExceptional scenario: If Customer does not have email id or unable to access the content on \nlink, then User will print entire AOF , take signature at the end of document, Capture the image \nof printed AOF (signed by customer) and submit for processing. Please note that this should be \ntreated as exceptional scenario.  \n• All the cases with wet signature will be referred to the Operations checker queue."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='ACCOUNT NUMBER GENERATION AND ACTIVATION OF CHANNELS \n(This step shall be allowed only after all the above steps are completed)  \nTo accommodate the cases where customer asks for a specific number as account \nnumber, system shall provide an option to user to enter the account number preferred \nby the customer and check whether the given number can be accepted. If acceptable, \nsystem shall assign the given number to the newly opened account. If not, available \noptions can be displayed, and user can select one among the available numbers. This \nfacility would be available for only high end schemes, as decided by Bank from time to \ntime. List of schemes for which this option is available will be provided separately.  \nSystem to call relevant APIs and get the customer ID/s created and account opened. \nAll processes must support comprehensive audit trails, exception handling, and escalation to \nbranch officers for unresolved issues. The system must display data source indicators (Aadhaar, \nUser Input) next to each field, allow editing of auto-populated fields with confirmation, and \nvalidate User ID preferences for uniqueness. The system must enforce mandatory consents for \ncredit checks, data sharing, and privacy policy, with optional marketing consent. \n \nInitial Remittance \nTo ensure new accounts are funded promptly and to avoid prolonged zero-balance accounts, \nthe system introduces the collection of Initial Remittance during account opening. This step \nintegrates with a payment gateway (EaseBuzz) and supports UPI, Debit Card, and NetBanking as \nmodes of payment.  \nOnce the user agrees for “Initial Remittance”, the system will generate a payment link and QR \nfor the user to make the payment. If the user opts to skip remittance, a reason must be \nrecorded; blank or invalid skip reasons are not permitted \nThe status of an initial remittance transaction will always fall into one of the following \ncategories:  \n• Success – Remittance completed; funds pending settlement into new account.  \n• Failure – Transaction failed; funds not received by the bank.  \n• Refunded – Remittance succeeded but funds were refunded due to account rejection or \ndelay.  \n• Settled – Remittance succeeded; funds credited to the newly opened account.  \n \nThe customer should be asked if they want to proceed to vKYC immediately or schedule it for a \nlater date/time.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Annex 1 – Declarations \n \n(This shall be displayed incase customer is “Non literate” selected in the customer educational \nqualification): Given that the customer is non literate, the requisite information furnished to the \nbank/agent is filled in this application form and read out to the person. The signature/Thumb \nimpression of the applicants shall be deemed as a confirmation for reading out the contents of \nthe form and its correctness. [Descoped] \nImplement this: Before form signing, show this declaration  \nBriefed the customer to provide accurate and complete information in the form and confirmed \nthat the information filled in fields like Income, Source of income/ Wealth, Occupation, business \nactivity, purpose of account opening and expected account turnover are once again verified with \nthe customer(s).If the customer falls into subcategory of the occupation, it has been invariably \nensured by the branch official/s. In the case of Enhanced Due Diligence, we confirm collection \nand recording of additional document/ information as per the guidance note on Account opening \n& Customer Due Diligence.  \n \nAnnex 2 – Enhanced Due Diligence \nEnhanced Due Diligence (EDD) refers to additional measures undertaken beyond standard due \ndiligence, specifically for customers classified as high-risk. These measures also include \ncollecting further information from applicants identified as high-risk based on parameters such \nas Occupation Code, Country Code, and High Net Worth Individual (HNI) status.  \nThe list of questions is \ngiven below. Sl. No.  \nQuestion  Options / Input Format  \n1  Do you have any ongoing \nentrepreneurial or \ncommercial ventures?  \ni) No, I am salaried ii) Yes, I \nam the sole owner iii) Yes, I \nco-own the business with \nothers  \n2  If you are running a business:  \n2.1  Briefly describe the nature \nof your business.  \n(Descriptive – one to two \nsentences)  \n2.2  Number of employees  ……………….(Enter numeric \nvalue only)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='2.3 a)  Do you have inward and \noutward remittances \nrelated to your business \nactivity?  \ni) Yes ii) No  \n2.3 b)  If yes: i) What is the total \nvalue and volume of \nremittances per month? ii) \nWhat is the average ticket \nsize?  \ni) ……………….. (Value in \nnumbers)  \nii) ……………….. (Value in \nnumbers)  \n2.4  Do you receive payments in \ncash for your business?  \ni)More than 50% in cash ii) \n100% in cash  \niii) Less than 50% in cash  \n2.5  Do you operate in multiple \nlocations?  \ni) Yes, within the country ii) \nYes, in multiple countries \niii) No, only at a single \n(registered) location')]

# %%
text_splitter=RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=100)

# %%
new_docs=text_splitter.split_documents(documents=docs)
new_docs
# Out:
# [Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='Business Requirements Document (BRD) – Savings Account Opening \nProduct: Savings Account | Region: India | Created on: 3 Sept 2025 \n \n1. Introduction'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='Product: Savings Account | Region: India | Created on: 3 Sept 2025 \n \n1. Introduction \nThis document specifies the business requirements for a fully digital, Agentic AI–enabled'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='This document specifies the business requirements for a fully digital, Agentic AI–enabled \nSavings Account opening journey. The objective is to capture, validate, and process'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='Savings Account opening journey. The objective is to capture, validate, and process \ncustomer information with high data quality, seamless user experience, and compliance'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='customer information with high data quality, seamless user experience, and compliance \nwith KYC/AML and bank policies. \n2. Scope \nIn Scope:'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='with KYC/AML and bank policies. \n2. Scope \nIn Scope: \n• End-to-end digital onboarding flow for Savings Account applicants \n• Field-level validations, real-time error handling, and exception workflow'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Field-level validations, real-time error handling, and exception workflow \n• Agentic AI assistance for data extraction, auto-fill, and proactive checks \n• Document capture, OCR, and verification'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Document capture, OCR, and verification \n• ETB/NTB journeys \n• DIY/assisted journeys \nOut of Scope: \n• Downstream debit card/courier logistics  \n• Non-savings products \n3. Eligibility Criteria'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content="• Downstream debit card/courier logistics  \n• Non-savings products \n3. Eligibility Criteria \n• Applicant's age/DOB must satisfy bank policy; DOB must be a valid past date."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content="• Applicant's age/DOB must satisfy bank policy; DOB must be a valid past date. \n• Residents and non-residents are eligible as per KYC and product policy; residency"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Residents and non-residents are eligible as per KYC and product policy; residency \nstatus must be captured accurately. \n• Nationality/citizenship must be declared and should not match any'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Nationality/citizenship must be declared and should not match any \nrestricted/sanctions list. \n• Applicants must pass PEP/sanctions screening in line with AML requirements.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Applicants must pass PEP/sanctions screening in line with AML requirements. \n• Valid KYC documents (identity and address proof) must be provided per regulatory \nnorms.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='• Valid KYC documents (identity and address proof) must be provided per regulatory \nnorms. \n• Both salaried and self-employed applicants are supported; employment/occupation'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 0, 'page_label': '1'}, page_content='norms. \n• Both salaried and self-employed applicants are supported; employment/occupation \ndetails must be declared.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='4. Business Rules \nThe savings account opening process applies to both existing bank customers (ETB) and new-to-'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='The savings account opening process applies to both existing bank customers (ETB) and new-to-\nbank (NTB) customers, supporting individual, joint, and salary account types for residents and'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='bank (NTB) customers, supporting individual, joint, and salary account types for residents and \nnon-residents. The system must accommodate salaried employees, self-employed individuals,'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='non-residents. The system must accommodate salaried employees, self-employed individuals, \nprofessionals, and other occupation categories, with special provisions for differently abled'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='professionals, and other occupation categories, with special provisions for differently abled \napplicants requiring assistance. For DIY or assisted journeys, the user should be able to upload'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='applicants requiring assistance. For DIY or assisted journeys, the user should be able to upload \nmultiple documents and use multi-prompts as inputs. The only difference in DIY and Assisted'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='multiple documents and use multi-prompts as inputs. The only difference in DIY and Assisted \njourneys would be identification of user persona : customer vs Branch staff. The remaining'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='journeys would be identification of user persona : customer vs Branch staff. The remaining \njourney remains the same.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='journey remains the same. \nAll applicants must provide their full legal name with first name mandatory for all applicants,'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='All applicants must provide their full legal name with first name mandatory for all applicants, \nmiddle name optional, and last name mandatory for all applicants - all in valid alphabetic text'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='middle name optional, and last name mandatory for all applicants - all in valid alphabetic text \nformat. The form date is auto-captured by the system in DD/MM/YYYY format. Applicants must'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='format. The form date is auto-captured by the system in DD/MM/YYYY format. Applicants must \nselect a valid title (Mr., Mrs., Ms., Dr., etc.) from the predefined list.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='select a valid title (Mr., Mrs., Ms., Dr., etc.) from the predefined list.  \nContact information requirements are strict: a valid 10-digit mobile number in numeric format is'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Contact information requirements are strict: a valid 10-digit mobile number in numeric format is \nmandatory, while residential phone number (if provided) must be in valid numeric format. Email'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='mandatory, while residential phone number (if provided) must be in valid numeric format. Email \naddresses must be in standard format. If email address is not available, then the applicant has to'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='addresses must be in standard format. If email address is not available, then the applicant has to \nsubmit a declaration as per Annexure 1'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='submit a declaration as per Annexure 1 \nWith the mobile number, the system should check if the mobile number exists in CBS and'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='With the mobile number, the system should check if the mobile number exists in CBS and \nwhether the customer is an existing to bank customer. If the mobile number is found, the'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='whether the customer is an existing to bank customer. If the mobile number is found, the \ncustomer can be asked to input PAN # or Account # to do a unique match'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='customer can be asked to input PAN # or Account # to do a unique match \nThe applicant has to choose the type of account & purpose.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='The applicant has to choose the type of account & purpose.  \nFor identity verification, NTB applicants must provide their PAN card and Aadhar card.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='For identity verification, NTB applicants must provide their PAN card and Aadhar card.  \nFor ETB, the system first needs to check if re-KYC is due. If re-KYC is due, ask for Aadhar Card and'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='PAN Card.  \nAcross applicants, If Aadhar card is not available, they should share another officially valid \ndocument (OVD), namely,  \nDriving Licence (Yes/No) \nVoter ID (Yes/No) \nPassport (Yes/No)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='document (OVD), namely,  \nDriving Licence (Yes/No) \nVoter ID (Yes/No) \nPassport (Yes/No) \nNREGA (Yes/No) \nLetter from National Population Register (Yes/No)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 1, 'page_label': '2'}, page_content='Passport (Yes/No) \nNREGA (Yes/No) \nLetter from National Population Register (Yes/No) \n \nThey should also submit other OVDs in case  \n• Mobile number of the applicant is not linked to Aadhar'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='• Any discrepancy in other details on Aadhar. Example, name as per Aadhar is John Joshua \nDallas but the customer wants to use John Dallas, then he will have to use another OVD'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Dallas but the customer wants to use John Dallas, then he will have to use another OVD \nThe corresponding document number must be provided in valid alphanumeric format matching'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='The corresponding document number must be provided in valid alphanumeric format matching \nthe selected OVD type.  \n• For Aadhaar, a valid 12-digit number is required'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='the selected OVD type.  \n• For Aadhaar, a valid 12-digit number is required \n• for PAN, a valid 10-character alphanumeric number \n• for Passport,  \no a valid passport number in correct format'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='• for Passport,  \no a valid passport number in correct format \no Place of issue \no Date of issue \no Date of expiry \n• For Driving License \no valid issue date'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='o Place of issue \no Date of issue \no Date of expiry \n• For Driving License \no valid issue date \no place of issue must be provided in valid text format \no valid driving license number'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='o place of issue must be provided in valid text format \no valid driving license number \n• If NREGA is selected, a valid NREGA card number must be provided; if NPR letter is'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='• If NREGA is selected, a valid NREGA card number must be provided; if NPR letter is \nselected, a valid NPR reference number is required.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='selected, a valid NPR reference number is required. \nDate of birth must be provided in DD/MM/YYYY format with validation ensuring the applicant is'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Date of birth must be provided in DD/MM/YYYY format with validation ensuring the applicant is \nat least 18 years old (except for minors with guardians), and gender must be selected from'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='at least 18 years old (except for minors with guardians), and gender must be selected from \nMale, Female, or Other options. Name, Photo, Date of Birth and Gender must be extracted from'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Male, Female, or Other options. Name, Photo, Date of Birth and Gender must be extracted from \nAadhar card or PAN card. Marital status (Single, Married, Divorced, Widowed) is optional. For an'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Aadhar card or PAN card. Marital status (Single, Married, Divorced, Widowed) is optional. For an \nETB customer, these details can be extracted from CBS.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='ETB customer, these details can be extracted from CBS. \nFather’s/Spouse first name with last name also mandatory, along with permanent address must'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Father’s/Spouse first name with last name also mandatory, along with permanent address must \nbe extracted from PAN and Aadhar card. For an ETB customer, these details can be extracted \nfrom CBS.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='from CBS. \nThe pin code of current address should be checked for cybercrime hotspots - Individual cust ids'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='The pin code of current address should be checked for cybercrime hotspots - Individual cust ids \nwith mentioned 3457 pin codes identified as Cyber hotspots in communication (mailing) address'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='with mentioned 3457 pin codes identified as Cyber hotspots in communication (mailing) address \nand the age of the customer is 18 - 25 years are classified with High Risk. Customers with'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='and the age of the customer is 18 - 25 years are classified with High Risk. Customers with \noccupation “Salaried” and STAFF = Y need to be excluded from this logic. If the customer'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='occupation “Salaried” and STAFF = Y need to be excluded from this logic. If the customer \naddress belongs to this criteria, then Enhanced due diligence as per Annexure 2 will kick in'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='address belongs to this criteria, then Enhanced due diligence as per Annexure 2 will kick in \nOnce the documents are uploaded, there needs to be checks and validations'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='Once the documents are uploaded, there needs to be checks and validations \n1. Forgery check – whether the document is tampered \n2. AML validations using external APIs'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 2, 'page_label': '3'}, page_content='1. Forgery check – whether the document is tampered \n2. AML validations using external APIs \n3. Fraud checks using internal APIs \n4. Consistency check across documents'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Occupation details vary by applicant type. Salaried individuals must provide their \norganization/employer name, designation/profession in valid text format. The number of years'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='organization/employer name, designation/profession in valid text format. The number of years \nemployed must be a valid non-negative numeric value. Self-employed applicants must provide a'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='employed must be a valid non-negative numeric value. Self-employed applicants must provide a \nvalid description of their business nature in descriptive text. All applicants must select their'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='valid description of their business nature in descriptive text. All applicants must select their \nsource of income from the predefined list (Salary, Business, Agriculture, etc.) and provide gross'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='source of income from the predefined list (Salary, Business, Agriculture, etc.) and provide gross \nannual income and net monthly income in valid numeric format. Source of funds or wealth must'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='annual income and net monthly income in valid numeric format. Source of funds or wealth must \nbe declared and the values can be \n• Salary  \n• Business Income  \n• Parents/Spouse/Siblings'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='be declared and the values can be \n• Salary  \n• Business Income  \n• Parents/Spouse/Siblings  \n• Personal Saving  \n• Rent/interest  \n• Agriculture  \n• Investments  \n• Retirement Benefits'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='• Personal Saving  \n• Rent/interest  \n• Agriculture  \n• Investments  \n• Retirement Benefits  \n \nBank employees must declare their status and provide their employer bank name, branch,'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Bank employees must declare their status and provide their employer bank name, branch, \noffice, employee ID or PF number, and current designation. All applicants must declare whether'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content="office, employee ID or PF number, and current designation. All applicants must declare whether \nthey're related to bank staff or directors, and if yes, must provide the full name of the related"),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content="they're related to bank staff or directors, and if yes, must provide the full name of the related \nperson."),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='person. \nThe system should be able to recommend a product to the applicant basis the eligibility criteria \nas per attached product scheme, also captured in the table below \nProduct%20Schemes.\nxlsx'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='as per attached product scheme, also captured in the table below \nProduct%20Schemes.\nxlsx\n \nSl. \nNo. Scheme Account \nType Eligibility Age Gend\ner AMB \n1 Bespoke Savings'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='xlsx\n \nSl. \nNo. Scheme Account \nType Eligibility Age Gend\ner AMB \n1 Bespoke Savings \nAccount Savings Resident Individual Age>18 M/F Rs. 2 lakhs \n2 Celesta Resident Savings'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Account Savings Resident Individual Age>18 M/F Rs. 2 lakhs \n2 Celesta Resident Savings \nAMB of ₹10 Lakhs in Celesta Savings \nAccount \nAMB of ₹10 Lakhs across all savings \naccounts'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='AMB of ₹10 Lakhs in Celesta Savings \nAccount \nAMB of ₹10 Lakhs across all savings \naccounts \nSalary credit >= ₹2 Lakhs \nAMB of ₹5 Lakhs across all savings \naccount + TD of ₹25 Lakhs \nTRV of ₹1 Crore'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='AMB of ₹5 Lakhs across all savings \naccount + TD of ₹25 Lakhs \nTRV of ₹1 Crore \n>18 M/F Rs.100000\n0 \n3 Club Savings Account Savings Resident Individuals of Metro Branches  >18 M/F Rs.5000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='0 \n3 Club Savings Account Savings Resident Individuals of Metro Branches  >18 M/F Rs.5000 \n4 Delite Savings Account Savings Resident Individuals of Semi-urban/Urban \nBranches >18 M/F RS.3000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 3, 'page_label': '4'}, page_content='Branches >18 M/F RS.3000 \n5 Fed Excel Savings \nAccount Savings \nProfessionals/Promoters of business/ \nRegistered member of JCI, FICCI AND \nChamber of Commerce \n>18 M/F Rs. 10,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='6 Fed Power Plus Savings Resident Individuals >18 M/F Rs.25000 \n7 Fed Smart Savings Resident Individuals >18 M/F Rs.100000 \n8 Fed First Savings Resident Individuals/Minors \nAge: 1 \nday to < \n18 years'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='8 Fed First Savings Resident Individuals/Minors \nAge: 1 \nday to < \n18 years \nM/F Rs.1000 \n9 Imperio Savings \nAccount Savings Sal >= 1L >18 M/F Rs.200000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='day to < \n18 years \nM/F Rs.1000 \n9 Imperio Savings \nAccount Savings Sal >= 1L >18 M/F Rs.200000 \n10 Mahila Mitra Plus Savings Resident Individuals/Female >18 F \nMetro/Ur\nban \nBranch – \nRs.10,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='10 Mahila Mitra Plus Savings Resident Individuals/Female >18 F \nMetro/Ur\nban \nBranch – \nRs.10,000 \nSemi \nUrban \nBranch – \nRs.7,500 \nRural \nBranch – \nRs.5,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Metro/Ur\nban \nBranch – \nRs.10,000 \nSemi \nUrban \nBranch – \nRs.7,500 \nRural \nBranch – \nRs.5,000 \n11 Pride Savings Account Savings Resident Individuals/ Non-Individuals of \nRural Branches \n M/F Rs.2000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Rural Branches \n M/F Rs.2000 \n12 SB Plus Savings Resident Individuals >18 M/F Rs.5000 \n17 Esteem Savings \nAccount Savings Resident Indian Citizens 55 & \nabove M/F Rs.50,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='17 Esteem Savings \nAccount Savings Resident Indian Citizens 55 & \nabove M/F Rs.50,000 \n13 Stellar Savings Account Savings Resident Individuals >18 M/F Rs. 10,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='above M/F Rs.50,000 \n13 Stellar Savings Account Savings Resident Individuals >18 M/F Rs. 10,000 \n14 Yuvamitra - Students Savings Resident Individuals + Students 18-25 M/F Nil'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='14 Yuvamitra - Students Savings Resident Individuals + Students 18-25 M/F Nil \n15 Fed Salary Premium Savings Resident Individuals/ Salary >30000 >18 M/F nil'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='15 Fed Salary Premium Savings Resident Individuals/ Salary >30000 >18 M/F nil \n Fed Classic Eazy Savings Resident Individuals/ Salary <10000 >18 M/F Nil'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Fed Classic Eazy Savings Resident Individuals/ Salary <10000 >18 M/F Nil \n16 Fed Salary Savings Resident Individuals/ Salary 10000-30000 >18 M/F nil \n18 GovEarn Salary'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='16 Fed Salary Savings Resident Individuals/ Salary 10000-30000 >18 M/F nil \n18 GovEarn Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.25,000 >18 M/F Nil'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Account Savings Resident Individuals + Gov. Employees + \nSalary>Rs.25,000 >18 M/F Nil \n19 GovEarn Prime Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.75,000 >18 M/F Nil'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Account Savings Resident Individuals + Gov. Employees + \nSalary>Rs.75,000 >18 M/F Nil \n20 Current Plus Current Resident Individuals >18 M/F Rs. 10,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='Salary>Rs.75,000 >18 M/F Nil \n20 Current Plus Current Resident Individuals >18 M/F Rs. 10,000 \n21 Fed Prime Current Resident Individuals >18 M/F Rs.25Lakh'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='21 Fed Prime Current Resident Individuals >18 M/F Rs.25Lakh \n22 Fed Trade Current Resident Individuals >18 M/F Rs.25,000 \n23 Fed Trade 50 Current Resident Individuals >18 M/F Rs.50,000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='23 Fed Trade 50 Current Resident Individuals >18 M/F Rs.50,000 \n24 Fed Trade Plus Current Resident Individuals >18 M/F Rs.100000 \n25 Fed Vanijya Current Resident Individuals >18 M/F Rs.500000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='25 Fed Vanijya Current Resident Individuals >18 M/F Rs.500000 \n26 Fed Vanijya Plus Current Resident Individuals >18 M/F Rs. 10 \nlakh \n27 Freedom Current Current Resident Individuals >18 M/F Rs.5000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='lakh \n27 Freedom Current Current Resident Individuals >18 M/F Rs.5000 \n28 Sweep Plus Current \nAccount Current Resident Individuals >18 M/F Rs.300000'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='28 Sweep Plus Current \nAccount Current Resident Individuals >18 M/F Rs.300000 \n \nFor joint accounts, if the primary applicant says there will be a joint-account holder, the agent'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='For joint accounts, if the primary applicant says there will be a joint-account holder, the agent \nshould ask for the co-applicant’s mobile number and PAN/Aadhar, generate a link and send a'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='should ask for the co-applicant’s mobile number and PAN/Aadhar, generate a link and send a \nlink to the co-applicant to fill in their details which would be same fields required as that of'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='link to the co-applicant to fill in their details which would be same fields required as that of \nprimary applicant.  \nValue added services'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 4, 'page_label': '5'}, page_content='primary applicant.  \nValue added services \n The applicant should confirm the value added services they want to opt out of'),
# ...
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='the system introduces the collection of Initial Remittance during account opening. This step \nintegrates with a payment gateway (EaseBuzz) and supports UPI, Debit Card, and NetBanking as'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='integrates with a payment gateway (EaseBuzz) and supports UPI, Debit Card, and NetBanking as \nmodes of payment.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='modes of payment.  \nOnce the user agrees for “Initial Remittance”, the system will generate a payment link and QR'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='Once the user agrees for “Initial Remittance”, the system will generate a payment link and QR \nfor the user to make the payment. If the user opts to skip remittance, a reason must be'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='for the user to make the payment. If the user opts to skip remittance, a reason must be \nrecorded; blank or invalid skip reasons are not permitted'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='recorded; blank or invalid skip reasons are not permitted \nThe status of an initial remittance transaction will always fall into one of the following \ncategories:'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='categories:  \n• Success – Remittance completed; funds pending settlement into new account.  \n• Failure – Transaction failed; funds not received by the bank.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='• Failure – Transaction failed; funds not received by the bank.  \n• Refunded – Remittance succeeded but funds were refunded due to account rejection or \ndelay.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='• Refunded – Remittance succeeded but funds were refunded due to account rejection or \ndelay.  \n• Settled – Remittance succeeded; funds credited to the newly opened account.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='delay.  \n• Settled – Remittance succeeded; funds credited to the newly opened account.  \n \nThe customer should be asked if they want to proceed to vKYC immediately or schedule it for a'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 9, 'page_label': '10'}, page_content='The customer should be asked if they want to proceed to vKYC immediately or schedule it for a \nlater date/time.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Annex 1 – Declarations \n \n(This shall be displayed incase customer is “Non literate” selected in the customer educational'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='(This shall be displayed incase customer is “Non literate” selected in the customer educational \nqualification): Given that the customer is non literate, the requisite information furnished to the'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='bank/agent is filled in this application form and read out to the person. The signature/Thumb \nimpression of the applicants shall be deemed as a confirmation for reading out the contents of'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='impression of the applicants shall be deemed as a confirmation for reading out the contents of \nthe form and its correctness. [Descoped] \nImplement this: Before form signing, show this declaration'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Implement this: Before form signing, show this declaration  \nBriefed the customer to provide accurate and complete information in the form and confirmed'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Briefed the customer to provide accurate and complete information in the form and confirmed \nthat the information filled in fields like Income, Source of income/ Wealth, Occupation, business'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='that the information filled in fields like Income, Source of income/ Wealth, Occupation, business \nactivity, purpose of account opening and expected account turnover are once again verified with'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='activity, purpose of account opening and expected account turnover are once again verified with \nthe customer(s).If the customer falls into subcategory of the occupation, it has been invariably'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='the customer(s).If the customer falls into subcategory of the occupation, it has been invariably \nensured by the branch official/s. In the case of Enhanced Due Diligence, we confirm collection'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='ensured by the branch official/s. In the case of Enhanced Due Diligence, we confirm collection \nand recording of additional document/ information as per the guidance note on Account opening'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='and recording of additional document/ information as per the guidance note on Account opening \n& Customer Due Diligence.  \n \nAnnex 2 – Enhanced Due Diligence'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='& Customer Due Diligence.  \n \nAnnex 2 – Enhanced Due Diligence \nEnhanced Due Diligence (EDD) refers to additional measures undertaken beyond standard due'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='Enhanced Due Diligence (EDD) refers to additional measures undertaken beyond standard due \ndiligence, specifically for customers classified as high-risk. These measures also include'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='diligence, specifically for customers classified as high-risk. These measures also include \ncollecting further information from applicants identified as high-risk based on parameters such'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='collecting further information from applicants identified as high-risk based on parameters such \nas Occupation Code, Country Code, and High Net Worth Individual (HNI) status.'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='as Occupation Code, Country Code, and High Net Worth Individual (HNI) status.  \nThe list of questions is \ngiven below. Sl. No.  \nQuestion  Options / Input Format  \n1  Do you have any ongoing'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='given below. Sl. No.  \nQuestion  Options / Input Format  \n1  Do you have any ongoing \nentrepreneurial or \ncommercial ventures?  \ni) No, I am salaried ii) Yes, I \nam the sole owner iii) Yes, I'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='commercial ventures?  \ni) No, I am salaried ii) Yes, I \nam the sole owner iii) Yes, I \nco-own the business with \nothers  \n2  If you are running a business:  \n2.1  Briefly describe the nature'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 10, 'page_label': '11'}, page_content='others  \n2  If you are running a business:  \n2.1  Briefly describe the nature \nof your business.  \n(Descriptive – one to two \nsentences)  \n2.2  Number of employees  ……………….(Enter numeric \nvalue only)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='2.3 a)  Do you have inward and \noutward remittances \nrelated to your business \nactivity?  \ni) Yes ii) No  \n2.3 b)  If yes: i) What is the total \nvalue and volume of \nremittances per month? ii)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='2.3 b)  If yes: i) What is the total \nvalue and volume of \nremittances per month? ii) \nWhat is the average ticket \nsize?  \ni) ……………….. (Value in \nnumbers)  \nii) ……………….. (Value in \nnumbers)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='size?  \ni) ……………….. (Value in \nnumbers)  \nii) ……………….. (Value in \nnumbers)  \n2.4  Do you receive payments in \ncash for your business?  \ni)More than 50% in cash ii) \n100% in cash'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='cash for your business?  \ni)More than 50% in cash ii) \n100% in cash  \niii) Less than 50% in cash  \n2.5  Do you operate in multiple \nlocations?  \ni) Yes, within the country ii)'),
#  Document(metadata={'producer': 'PyPDF', 'creator': 'Microsoft Word', 'creationdate': '2025-09-10T01:48:55-07:00', 'author': 'python-docx', 'moddate': '2025-09-10T01:48:55-07:00', 'source': '../docs//BRD.pdf', 'total_pages': 12, 'page': 11, 'page_label': '12'}, page_content='2.5  Do you operate in multiple \nlocations?  \ni) Yes, within the country ii) \nYes, in multiple countries \niii) No, only at a single \n(registered) location')]

# %%
doc_string=[docs.page_content for docs in new_docs]
doc_string
# Out:
# ['Business Requirements Document (BRD) – Savings Account Opening \nProduct: Savings Account | Region: India | Created on: 3 Sept 2025 \n \n1. Introduction',
#  'Product: Savings Account | Region: India | Created on: 3 Sept 2025 \n \n1. Introduction \nThis document specifies the business requirements for a fully digital, Agentic AI–enabled',
#  'This document specifies the business requirements for a fully digital, Agentic AI–enabled \nSavings Account opening journey. The objective is to capture, validate, and process',
#  'Savings Account opening journey. The objective is to capture, validate, and process \ncustomer information with high data quality, seamless user experience, and compliance',
#  'customer information with high data quality, seamless user experience, and compliance \nwith KYC/AML and bank policies. \n2. Scope \nIn Scope:',
#  'with KYC/AML and bank policies. \n2. Scope \nIn Scope: \n• End-to-end digital onboarding flow for Savings Account applicants \n• Field-level validations, real-time error handling, and exception workflow',
#  '• Field-level validations, real-time error handling, and exception workflow \n• Agentic AI assistance for data extraction, auto-fill, and proactive checks \n• Document capture, OCR, and verification',
#  '• Document capture, OCR, and verification \n• ETB/NTB journeys \n• DIY/assisted journeys \nOut of Scope: \n• Downstream debit card/courier logistics  \n• Non-savings products \n3. Eligibility Criteria',
#  "• Downstream debit card/courier logistics  \n• Non-savings products \n3. Eligibility Criteria \n• Applicant's age/DOB must satisfy bank policy; DOB must be a valid past date.",
#  "• Applicant's age/DOB must satisfy bank policy; DOB must be a valid past date. \n• Residents and non-residents are eligible as per KYC and product policy; residency",
#  '• Residents and non-residents are eligible as per KYC and product policy; residency \nstatus must be captured accurately. \n• Nationality/citizenship must be declared and should not match any',
#  '• Nationality/citizenship must be declared and should not match any \nrestricted/sanctions list. \n• Applicants must pass PEP/sanctions screening in line with AML requirements.',
#  '• Applicants must pass PEP/sanctions screening in line with AML requirements. \n• Valid KYC documents (identity and address proof) must be provided per regulatory \nnorms.',
#  '• Valid KYC documents (identity and address proof) must be provided per regulatory \nnorms. \n• Both salaried and self-employed applicants are supported; employment/occupation',
#  'norms. \n• Both salaried and self-employed applicants are supported; employment/occupation \ndetails must be declared.',
#  '4. Business Rules \nThe savings account opening process applies to both existing bank customers (ETB) and new-to-',
#  'The savings account opening process applies to both existing bank customers (ETB) and new-to-\nbank (NTB) customers, supporting individual, joint, and salary account types for residents and',
#  'bank (NTB) customers, supporting individual, joint, and salary account types for residents and \nnon-residents. The system must accommodate salaried employees, self-employed individuals,',
#  'non-residents. The system must accommodate salaried employees, self-employed individuals, \nprofessionals, and other occupation categories, with special provisions for differently abled',
#  'professionals, and other occupation categories, with special provisions for differently abled \napplicants requiring assistance. For DIY or assisted journeys, the user should be able to upload',
#  'applicants requiring assistance. For DIY or assisted journeys, the user should be able to upload \nmultiple documents and use multi-prompts as inputs. The only difference in DIY and Assisted',
#  'multiple documents and use multi-prompts as inputs. The only difference in DIY and Assisted \njourneys would be identification of user persona : customer vs Branch staff. The remaining',
#  'journeys would be identification of user persona : customer vs Branch staff. The remaining \njourney remains the same.',
#  'journey remains the same. \nAll applicants must provide their full legal name with first name mandatory for all applicants,',
#  'All applicants must provide their full legal name with first name mandatory for all applicants, \nmiddle name optional, and last name mandatory for all applicants - all in valid alphabetic text',
#  'middle name optional, and last name mandatory for all applicants - all in valid alphabetic text \nformat. The form date is auto-captured by the system in DD/MM/YYYY format. Applicants must',
#  'format. The form date is auto-captured by the system in DD/MM/YYYY format. Applicants must \nselect a valid title (Mr., Mrs., Ms., Dr., etc.) from the predefined list.',
#  'select a valid title (Mr., Mrs., Ms., Dr., etc.) from the predefined list.  \nContact information requirements are strict: a valid 10-digit mobile number in numeric format is',
#  'Contact information requirements are strict: a valid 10-digit mobile number in numeric format is \nmandatory, while residential phone number (if provided) must be in valid numeric format. Email',
#  'mandatory, while residential phone number (if provided) must be in valid numeric format. Email \naddresses must be in standard format. If email address is not available, then the applicant has to',
#  'addresses must be in standard format. If email address is not available, then the applicant has to \nsubmit a declaration as per Annexure 1',
#  'submit a declaration as per Annexure 1 \nWith the mobile number, the system should check if the mobile number exists in CBS and',
#  'With the mobile number, the system should check if the mobile number exists in CBS and \nwhether the customer is an existing to bank customer. If the mobile number is found, the',
#  'whether the customer is an existing to bank customer. If the mobile number is found, the \ncustomer can be asked to input PAN # or Account # to do a unique match',
#  'customer can be asked to input PAN # or Account # to do a unique match \nThe applicant has to choose the type of account & purpose.',
#  'The applicant has to choose the type of account & purpose.  \nFor identity verification, NTB applicants must provide their PAN card and Aadhar card.',
#  'For identity verification, NTB applicants must provide their PAN card and Aadhar card.  \nFor ETB, the system first needs to check if re-KYC is due. If re-KYC is due, ask for Aadhar Card and',
#  'PAN Card.  \nAcross applicants, If Aadhar card is not available, they should share another officially valid \ndocument (OVD), namely,  \nDriving Licence (Yes/No) \nVoter ID (Yes/No) \nPassport (Yes/No)',
#  'document (OVD), namely,  \nDriving Licence (Yes/No) \nVoter ID (Yes/No) \nPassport (Yes/No) \nNREGA (Yes/No) \nLetter from National Population Register (Yes/No)',
#  'Passport (Yes/No) \nNREGA (Yes/No) \nLetter from National Population Register (Yes/No) \n \nThey should also submit other OVDs in case  \n• Mobile number of the applicant is not linked to Aadhar',
#  '• Any discrepancy in other details on Aadhar. Example, name as per Aadhar is John Joshua \nDallas but the customer wants to use John Dallas, then he will have to use another OVD',
#  'Dallas but the customer wants to use John Dallas, then he will have to use another OVD \nThe corresponding document number must be provided in valid alphanumeric format matching',
#  'The corresponding document number must be provided in valid alphanumeric format matching \nthe selected OVD type.  \n• For Aadhaar, a valid 12-digit number is required',
#  'the selected OVD type.  \n• For Aadhaar, a valid 12-digit number is required \n• for PAN, a valid 10-character alphanumeric number \n• for Passport,  \no a valid passport number in correct format',
#  '• for Passport,  \no a valid passport number in correct format \no Place of issue \no Date of issue \no Date of expiry \n• For Driving License \no valid issue date',
#  'o Place of issue \no Date of issue \no Date of expiry \n• For Driving License \no valid issue date \no place of issue must be provided in valid text format \no valid driving license number',
#  'o place of issue must be provided in valid text format \no valid driving license number \n• If NREGA is selected, a valid NREGA card number must be provided; if NPR letter is',
#  '• If NREGA is selected, a valid NREGA card number must be provided; if NPR letter is \nselected, a valid NPR reference number is required.',
#  'selected, a valid NPR reference number is required. \nDate of birth must be provided in DD/MM/YYYY format with validation ensuring the applicant is',
#  'Date of birth must be provided in DD/MM/YYYY format with validation ensuring the applicant is \nat least 18 years old (except for minors with guardians), and gender must be selected from',
#  'at least 18 years old (except for minors with guardians), and gender must be selected from \nMale, Female, or Other options. Name, Photo, Date of Birth and Gender must be extracted from',
#  'Male, Female, or Other options. Name, Photo, Date of Birth and Gender must be extracted from \nAadhar card or PAN card. Marital status (Single, Married, Divorced, Widowed) is optional. For an',
#  'Aadhar card or PAN card. Marital status (Single, Married, Divorced, Widowed) is optional. For an \nETB customer, these details can be extracted from CBS.',
#  'ETB customer, these details can be extracted from CBS. \nFather’s/Spouse first name with last name also mandatory, along with permanent address must',
#  'Father’s/Spouse first name with last name also mandatory, along with permanent address must \nbe extracted from PAN and Aadhar card. For an ETB customer, these details can be extracted \nfrom CBS.',
#  'from CBS. \nThe pin code of current address should be checked for cybercrime hotspots - Individual cust ids',
#  'The pin code of current address should be checked for cybercrime hotspots - Individual cust ids \nwith mentioned 3457 pin codes identified as Cyber hotspots in communication (mailing) address',
#  'with mentioned 3457 pin codes identified as Cyber hotspots in communication (mailing) address \nand the age of the customer is 18 - 25 years are classified with High Risk. Customers with',
#  'and the age of the customer is 18 - 25 years are classified with High Risk. Customers with \noccupation “Salaried” and STAFF = Y need to be excluded from this logic. If the customer',
#  'occupation “Salaried” and STAFF = Y need to be excluded from this logic. If the customer \naddress belongs to this criteria, then Enhanced due diligence as per Annexure 2 will kick in',
#  'address belongs to this criteria, then Enhanced due diligence as per Annexure 2 will kick in \nOnce the documents are uploaded, there needs to be checks and validations',
#  'Once the documents are uploaded, there needs to be checks and validations \n1. Forgery check – whether the document is tampered \n2. AML validations using external APIs',
#  '1. Forgery check – whether the document is tampered \n2. AML validations using external APIs \n3. Fraud checks using internal APIs \n4. Consistency check across documents',
#  'Occupation details vary by applicant type. Salaried individuals must provide their \norganization/employer name, designation/profession in valid text format. The number of years',
#  'organization/employer name, designation/profession in valid text format. The number of years \nemployed must be a valid non-negative numeric value. Self-employed applicants must provide a',
#  'employed must be a valid non-negative numeric value. Self-employed applicants must provide a \nvalid description of their business nature in descriptive text. All applicants must select their',
#  'valid description of their business nature in descriptive text. All applicants must select their \nsource of income from the predefined list (Salary, Business, Agriculture, etc.) and provide gross',
#  'source of income from the predefined list (Salary, Business, Agriculture, etc.) and provide gross \nannual income and net monthly income in valid numeric format. Source of funds or wealth must',
#  'annual income and net monthly income in valid numeric format. Source of funds or wealth must \nbe declared and the values can be \n• Salary  \n• Business Income  \n• Parents/Spouse/Siblings',
#  'be declared and the values can be \n• Salary  \n• Business Income  \n• Parents/Spouse/Siblings  \n• Personal Saving  \n• Rent/interest  \n• Agriculture  \n• Investments  \n• Retirement Benefits',
#  '• Personal Saving  \n• Rent/interest  \n• Agriculture  \n• Investments  \n• Retirement Benefits  \n \nBank employees must declare their status and provide their employer bank name, branch,',
#  'Bank employees must declare their status and provide their employer bank name, branch, \noffice, employee ID or PF number, and current designation. All applicants must declare whether',
#  "office, employee ID or PF number, and current designation. All applicants must declare whether \nthey're related to bank staff or directors, and if yes, must provide the full name of the related",
#  "they're related to bank staff or directors, and if yes, must provide the full name of the related \nperson.",
#  'person. \nThe system should be able to recommend a product to the applicant basis the eligibility criteria \nas per attached product scheme, also captured in the table below \nProduct%20Schemes.\nxlsx',
#  'as per attached product scheme, also captured in the table below \nProduct%20Schemes.\nxlsx\n \nSl. \nNo. Scheme Account \nType Eligibility Age Gend\ner AMB \n1 Bespoke Savings',
#  'xlsx\n \nSl. \nNo. Scheme Account \nType Eligibility Age Gend\ner AMB \n1 Bespoke Savings \nAccount Savings Resident Individual Age>18 M/F Rs. 2 lakhs \n2 Celesta Resident Savings',
#  'Account Savings Resident Individual Age>18 M/F Rs. 2 lakhs \n2 Celesta Resident Savings \nAMB of ₹10 Lakhs in Celesta Savings \nAccount \nAMB of ₹10 Lakhs across all savings \naccounts',
#  'AMB of ₹10 Lakhs in Celesta Savings \nAccount \nAMB of ₹10 Lakhs across all savings \naccounts \nSalary credit >= ₹2 Lakhs \nAMB of ₹5 Lakhs across all savings \naccount + TD of ₹25 Lakhs \nTRV of ₹1 Crore',
#  'AMB of ₹5 Lakhs across all savings \naccount + TD of ₹25 Lakhs \nTRV of ₹1 Crore \n>18 M/F Rs.100000\n0 \n3 Club Savings Account Savings Resident Individuals of Metro Branches  >18 M/F Rs.5000',
#  '0 \n3 Club Savings Account Savings Resident Individuals of Metro Branches  >18 M/F Rs.5000 \n4 Delite Savings Account Savings Resident Individuals of Semi-urban/Urban \nBranches >18 M/F RS.3000',
#  'Branches >18 M/F RS.3000 \n5 Fed Excel Savings \nAccount Savings \nProfessionals/Promoters of business/ \nRegistered member of JCI, FICCI AND \nChamber of Commerce \n>18 M/F Rs. 10,000',
#  '6 Fed Power Plus Savings Resident Individuals >18 M/F Rs.25000 \n7 Fed Smart Savings Resident Individuals >18 M/F Rs.100000 \n8 Fed First Savings Resident Individuals/Minors \nAge: 1 \nday to < \n18 years',
#  '8 Fed First Savings Resident Individuals/Minors \nAge: 1 \nday to < \n18 years \nM/F Rs.1000 \n9 Imperio Savings \nAccount Savings Sal >= 1L >18 M/F Rs.200000',
#  'day to < \n18 years \nM/F Rs.1000 \n9 Imperio Savings \nAccount Savings Sal >= 1L >18 M/F Rs.200000 \n10 Mahila Mitra Plus Savings Resident Individuals/Female >18 F \nMetro/Ur\nban \nBranch – \nRs.10,000',
#  '10 Mahila Mitra Plus Savings Resident Individuals/Female >18 F \nMetro/Ur\nban \nBranch – \nRs.10,000 \nSemi \nUrban \nBranch – \nRs.7,500 \nRural \nBranch – \nRs.5,000',
#  'Metro/Ur\nban \nBranch – \nRs.10,000 \nSemi \nUrban \nBranch – \nRs.7,500 \nRural \nBranch – \nRs.5,000 \n11 Pride Savings Account Savings Resident Individuals/ Non-Individuals of \nRural Branches \n M/F Rs.2000',
#  'Rural Branches \n M/F Rs.2000 \n12 SB Plus Savings Resident Individuals >18 M/F Rs.5000 \n17 Esteem Savings \nAccount Savings Resident Indian Citizens 55 & \nabove M/F Rs.50,000',
#  '17 Esteem Savings \nAccount Savings Resident Indian Citizens 55 & \nabove M/F Rs.50,000 \n13 Stellar Savings Account Savings Resident Individuals >18 M/F Rs. 10,000',
#  'above M/F Rs.50,000 \n13 Stellar Savings Account Savings Resident Individuals >18 M/F Rs. 10,000 \n14 Yuvamitra - Students Savings Resident Individuals + Students 18-25 M/F Nil',
#  '14 Yuvamitra - Students Savings Resident Individuals + Students 18-25 M/F Nil \n15 Fed Salary Premium Savings Resident Individuals/ Salary >30000 >18 M/F nil',
#  '15 Fed Salary Premium Savings Resident Individuals/ Salary >30000 >18 M/F nil \n Fed Classic Eazy Savings Resident Individuals/ Salary <10000 >18 M/F Nil',
#  'Fed Classic Eazy Savings Resident Individuals/ Salary <10000 >18 M/F Nil \n16 Fed Salary Savings Resident Individuals/ Salary 10000-30000 >18 M/F nil \n18 GovEarn Salary',
#  '16 Fed Salary Savings Resident Individuals/ Salary 10000-30000 >18 M/F nil \n18 GovEarn Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.25,000 >18 M/F Nil',
#  'Account Savings Resident Individuals + Gov. Employees + \nSalary>Rs.25,000 >18 M/F Nil \n19 GovEarn Prime Salary \nAccount Savings Resident Individuals + Gov. Employees + \nSalary>Rs.75,000 >18 M/F Nil',
#  'Account Savings Resident Individuals + Gov. Employees + \nSalary>Rs.75,000 >18 M/F Nil \n20 Current Plus Current Resident Individuals >18 M/F Rs. 10,000',
#  'Salary>Rs.75,000 >18 M/F Nil \n20 Current Plus Current Resident Individuals >18 M/F Rs. 10,000 \n21 Fed Prime Current Resident Individuals >18 M/F Rs.25Lakh',
#  '21 Fed Prime Current Resident Individuals >18 M/F Rs.25Lakh \n22 Fed Trade Current Resident Individuals >18 M/F Rs.25,000 \n23 Fed Trade 50 Current Resident Individuals >18 M/F Rs.50,000',
#  '23 Fed Trade 50 Current Resident Individuals >18 M/F Rs.50,000 \n24 Fed Trade Plus Current Resident Individuals >18 M/F Rs.100000 \n25 Fed Vanijya Current Resident Individuals >18 M/F Rs.500000',
#  '25 Fed Vanijya Current Resident Individuals >18 M/F Rs.500000 \n26 Fed Vanijya Plus Current Resident Individuals >18 M/F Rs. 10 \nlakh \n27 Freedom Current Current Resident Individuals >18 M/F Rs.5000',
#  'lakh \n27 Freedom Current Current Resident Individuals >18 M/F Rs.5000 \n28 Sweep Plus Current \nAccount Current Resident Individuals >18 M/F Rs.300000',
#  '28 Sweep Plus Current \nAccount Current Resident Individuals >18 M/F Rs.300000 \n \nFor joint accounts, if the primary applicant says there will be a joint-account holder, the agent',
#  'For joint accounts, if the primary applicant says there will be a joint-account holder, the agent \nshould ask for the co-applicant’s mobile number and PAN/Aadhar, generate a link and send a',
#  'should ask for the co-applicant’s mobile number and PAN/Aadhar, generate a link and send a \nlink to the co-applicant to fill in their details which would be same fields required as that of',
#  'link to the co-applicant to fill in their details which would be same fields required as that of \nprimary applicant.  \nValue added services',
#  'primary applicant.  \nValue added services \n The applicant should confirm the value added services they want to opt out of',
#  '• Passbook  \n• Mobile alerts  \n• Email Statement  \n• Physical Statement  \n• Mobile Banking (FedMobile)  \n• Internet banking (FedNet)  \n• AePS \n• Aadhaar Seeding  \n \n• Cheque book required',
#  '• Internet banking (FedNet)  \n• AePS \n• Aadhaar Seeding  \n \n• Cheque book required  \n• Debit card  \n• Customized Debit Card Type of Card (list of all cards eligible for the respective',
#  '• Debit card  \n• Customized Debit Card Type of Card (list of all cards eligible for the respective \nscheme shall be listed.)',
#  'scheme shall be listed.)  \n• Celesta & Imperio cards are only issued one per Cust ID even if the customer opens \nmultiple celesta/Imperio accounts.',
#  'multiple celesta/Imperio accounts.  \nNomination is optional with specific requirements \ni No  \nIf No, User should readout the following to customer.',
#  'i No  \nIf No, User should readout the following to customer.  \nI/ We have been explained by the bank official that the nomination facility is available. I/ We',
#  'I/ We have been explained by the bank official that the nomination facility is available. I/ We \nalso understood that this facility will enable the Bank to make the settlement to the nominee,',
#  'also understood that this facility will enable the Bank to make the settlement to the nominee, \nhassle free and without insisting any legal documents, in case of any unfortunate event of death.',
#  'hassle free and without insisting any legal documents, in case of any unfortunate event of death. \nAfter considering Bank’s request, I/we have decided not to provide the nomination and demand',
#  'After considering Bank’s request, I/we have decided not to provide the nomination and demand \nthat the Bank should open my/our account/s without nomination.  \nYes',
#  'that the Bank should open my/our account/s without nomination.  \nYes  \nIf Yes, User need to enter the following  \ni Enter Customer ID, if Nominee is existing customer of Federal bank',
#  'i Enter Customer ID, if Nominee is existing customer of Federal bank  \nii Name of the nominee \niii Address (If customer ID not entered, An option select the address of the',
#  'iii Address (If customer ID not entered, An option select the address of the \ndepositor/s shall be provided)  \niv Relationship with the depositor',
#  'v Age. If Age is below 18, Collect following details  \n• Date of birth  \n• Name of the Guardian/lawfully  \n• Address  \n• Age',
#  '• Date of birth  \n• Name of the Guardian/lawfully  \n• Address  \n• Age  \nSystem to auto populate values in the field ii, iii, & v if customer ID is entered in step i above.',
#  'All applications must undergo rigorous validation: mandatory fields must be complete with \nproper data types, signatures must be present in digital, e-sign, or wet-ink format, declarations',
#  'proper data types, signatures must be present in digital, e-sign, or wet-ink format, declarations \nmust be confirmed, and eligibility checks (age, income, risk profile) must be passed. The system',
#  'must be confirmed, and eligibility checks (age, income, risk profile) must be passed. The system \nmust perform duplicate application checks, sanction list screening, and real-time eligibility',
#  'must perform duplicate application checks, sanction list screening, and real-time eligibility \nchecks based on credit score and risk policy. All mandatory fields must be validated before',
#  'checks based on credit score and risk policy. All mandatory fields must be validated before \nsubmission. \nAll declarations, as applicable should be accepted by the customer',
#  'submission. \nAll declarations, as applicable should be accepted by the customer \nSystem requirements are comprehensive: unique application numbers and tracking IDs must be',
#  'System requirements are comprehensive: unique application numbers and tracking IDs must be \ngenerated for each submission; channel of application (Branch, Online, Mobile) must be',
#  'generated for each submission; channel of application (Branch, Online, Mobile) must be \nrecorded; session timeout must occur after 15 minutes of inactivity; all sensitive data must be',
#  'recorded; session timeout must occur after 15 minutes of inactivity; all sensitive data must be \nencrypted during transmission and storage; and compliance with data privacy regulations',
#  'encrypted during transmission and storage; and compliance with data privacy regulations \n(GDPR, local laws) is mandatory. The system must integrate with central KYC registry, credit',
#  '(GDPR, local laws) is mandatory. The system must integrate with central KYC registry, credit \nbureau, Aadhaar, PAN, MCA, and GSTN for real-time validation. OCR extraction from uploaded',
#  'bureau, Aadhaar, PAN, MCA, and GSTN for real-time validation. OCR extraction from uploaded \ndocuments must be supported with data validation against user input, and manual override',
#  'documents must be supported with data validation against user input, and manual override \nmust require justification.',
#  'must require justification. \nAn account opening form in standard template shall be created by auto populating the data',
#  'An account opening form in standard template shall be created by auto populating the data \ncaptured during the CIF creation and account opening journey. This template shall contain all',
#  'captured during the CIF creation and account opening journey. This template shall contain all \nthe terms and conditions. Our standard AOF template to be used.',
#  'the terms and conditions. Our standard AOF template to be used.  \nCustomer ID creation form in standard template shall be generated and displayed in the screen.',
#  'Customer ID creation form in standard template shall be generated and displayed in the screen. \nUser shall be given two options “Confirm & Proceed” and “Modify”(modification would not be',
#  'User shall be given two options “Confirm & Proceed” and “Modify”(modification would not be \nallowed for KYC details). In case of Confirm and proceed, user shall be taken to next step for',
#  'allowed for KYC details). In case of Confirm and proceed, user shall be taken to next step for \nsigning the AOF. If user click on Modify, they can update any information',
#  'signing the AOF. If user click on Modify, they can update any information  \nOption 1: E Sign (Available only for Aadhaar customers).',
#  'Option 1: E Sign (Available only for Aadhaar customers).  \nAadhar biometric based e signing  The auto populated account opening form is displayed in the',
#  'Aadhar biometric based e signing  The auto populated account opening form is displayed in the \nscreen, and customer reviews the same and does the biometric based e-sign using fingerprint',
#  'screen, and customer reviews the same and does the biometric based e-sign using fingerprint \n(fingerprint sensor connected to the device) or face authorization (through the camera attached',
#  '(fingerprint sensor connected to the device) or face authorization (through the camera attached \nwith the device).',
#  'with the device).  \nIn case the customer finds some information, which needs to be amended, the changes can be \nmade by user and trigger the e-signing process again.',
#  'Aadhar OTP based e sign  \nThe auto populated account opening form along with the Name, DOB, mobile number and email',
#  'The auto populated account opening form along with the Name, DOB, mobile number and email \nID (if available) shall be passed to e sign API. (Since there can be time gap between this step and',
#  'next step, system shall have provision to save the application and resume the process after \ngetting esign completion confirmation)',
#  'getting esign completion confirmation)  \nCustomer will receive the notification in the given mobile number and email ID (if available).',
#  'Customer will receive the notification in the given mobile number and email ID (if available).  \nCustomer to open the link, review the document and confirm the details and proceed with',
#  'Customer to open the link, review the document and confirm the details and proceed with \nAadhaar based e signing process.',
#  'Aadhaar based e signing process.  \nIn case the customer finds some information, which needs to be amended, the changes can be \nmade by user and resend the same to the customer again for e signing.',
#  'made by user and resend the same to the customer again for e signing.  \nOption 2: Digital signature  \nThe auto populated account opening form is sent to the customer mobile number and email ID',
#  'The auto populated account opening form is sent to the customer mobile number and email ID  \nCustomer reviews the document, sign it using the digital signature and send it back to the bank',
#  'Customer reviews the document, sign it using the digital signature and send it back to the bank \n(Since there can be time gap between this step',
#  '(Since there can be time gap between this step  \ni resume the process after getting the digitally signed application back)',
#  'i resume the process after getting the digitally signed application back)  \nii User to upload the digitally signed document and click on Verify Digital Signature',
#  'ii User to upload the digitally signed document and click on Verify Digital Signature \nbutton to confirm the validity of the digital signature',
#  'button to confirm the validity of the digital signature  \niii System to use eMudra APIs to verify the digital signature  \niv User shall be allowed to proceed if the digital signature is valid',
#  'iv User shall be allowed to proceed if the digital signature is valid  \nv If digital signature is not valid, user shall advice user to redo the digital signature or fall',
#  'v If digital signature is not valid, user shall advice user to redo the digital signature or fall \nback onto any other option to get the document authorized',
#  'back onto any other option to get the document authorized  \nOption 3: Wet signature in account opening form (Incase the eSign/Digital signature is not \npossible)',
#  'possible)  \nSystem shall give an option to generate One pager summary as per the template  \nANNEXURE%201-%2\n0One%20pager%20-%20V1.docx',
#  'ANNEXURE%201-%2\n0One%20pager%20-%20V1.docx\n \nUser can either print the document or manually prepare the document in the standard template \nand get it signed or thumb impression',
#  'User to upload/capture the signed document in the application If customer has provided email \nid in AOF 1 Pager would be wet signed by customer. User (Federal Branch Official) will capture',
#  'id in AOF 1 Pager would be wet signed by customer. User (Federal Branch Official) will capture \nimage of the document in AO Portal. User will submit the AOF for processing, this step will also',
#  'image of the document in AO Portal. User will submit the AOF for processing, this step will also \ntrigger email to customer a copy of entire AOF along with 1 pager signed by customer (this will 1',
#  'trigger email to customer a copy of entire AOF along with 1 pager signed by customer (this will 1 \nconsolidated document in PDF)  \n1 pager original to be retained at branch',
#  'consolidated document in PDF)  \n1 pager original to be retained at branch  \n2 Communication content in the email to be provided by Compliance team',
#  '2 Communication content in the email to be provided by Compliance team  \nThis customer authorization process shall be applicable for all applicant of the particular',
#  'This customer authorization process shall be applicable for all applicant of the particular \naccount. There may be multiple applicants for a single product, so there shall system validations',
#  'account. There may be multiple applicants for a single product, so there shall system validations \nand capability to capture all the customer authorization. User shall be able to proceed further',
#  'and capability to capture all the customer authorization. User shall be able to proceed further \nonly after the authorization by all customer is received.  \nProcess for 1 pager wet signature:',
#  "only after the authorization by all customer is received.  \nProcess for 1 pager wet signature:  \nIf e-sign and digital signature of AOF is not possible , Obtaining customer's signature on 1 pager",
#  "If e-sign and digital signature of AOF is not possible , Obtaining customer's signature on 1 pager \nin AOF  \n• If Customer does not have email id, 1 Pager would be wet signed by customer",
#  'in AOF  \n• If Customer does not have email id, 1 Pager would be wet signed by customer  \n• User (Federal Branch Official) will capture image of the document in AO Portal',
#  '• User (Federal Branch Official) will capture image of the document in AO Portal  \n• A link would be sent to customer in SMS',
#  '• A link would be sent to customer in SMS  \n• Link would contain AOF+1 pager(this will 1 consolidated document in PDF)  \n• Clicking the link would open the document',
#  '• Clicking the link would open the document  \n• Customer will read and review the document and agree to the content',
#  '• Customer will read and review the document and agree to the content  \n• At the end of documents placeholder would be provided for OTP sent by Federal bank \nthrough SMS on verified mobile',
#  'through SMS on verified mobile  \n• After entering OTP , Customer will submit and message would be received in AO Portal \nthrough backend. If OTP is matched, user will get the tab to proceed',
#  'through backend. If OTP is matched, user will get the tab to proceed  \n• User will submit AOF +1 Pager for processing  \n• 1 pager original to be retained at branch',
#  '• User will submit AOF +1 Pager for processing  \n• 1 pager original to be retained at branch  \nExceptional scenario: If Customer does not have email id or unable to access the content on',
#  'Exceptional scenario: If Customer does not have email id or unable to access the content on \nlink, then User will print entire AOF , take signature at the end of document, Capture the image',
#  'link, then User will print entire AOF , take signature at the end of document, Capture the image \nof printed AOF (signed by customer) and submit for processing. Please note that this should be',
#  'of printed AOF (signed by customer) and submit for processing. Please note that this should be \ntreated as exceptional scenario.',
#  'treated as exceptional scenario.  \n• All the cases with wet signature will be referred to the Operations checker queue.',
#  'ACCOUNT NUMBER GENERATION AND ACTIVATION OF CHANNELS \n(This step shall be allowed only after all the above steps are completed)',
#  '(This step shall be allowed only after all the above steps are completed)  \nTo accommodate the cases where customer asks for a specific number as account',
#  'To accommodate the cases where customer asks for a specific number as account \nnumber, system shall provide an option to user to enter the account number preferred',
#  'number, system shall provide an option to user to enter the account number preferred \nby the customer and check whether the given number can be accepted. If acceptable,',
#  'by the customer and check whether the given number can be accepted. If acceptable, \nsystem shall assign the given number to the newly opened account. If not, available',
#  'system shall assign the given number to the newly opened account. If not, available \noptions can be displayed, and user can select one among the available numbers. This',
#  'options can be displayed, and user can select one among the available numbers. This \nfacility would be available for only high end schemes, as decided by Bank from time to',
#  'facility would be available for only high end schemes, as decided by Bank from time to \ntime. List of schemes for which this option is available will be provided separately.',
#  'time. List of schemes for which this option is available will be provided separately.  \nSystem to call relevant APIs and get the customer ID/s created and account opened.',
#  'System to call relevant APIs and get the customer ID/s created and account opened. \nAll processes must support comprehensive audit trails, exception handling, and escalation to',
#  'All processes must support comprehensive audit trails, exception handling, and escalation to \nbranch officers for unresolved issues. The system must display data source indicators (Aadhaar,',
#  'branch officers for unresolved issues. The system must display data source indicators (Aadhaar, \nUser Input) next to each field, allow editing of auto-populated fields with confirmation, and',
#  'User Input) next to each field, allow editing of auto-populated fields with confirmation, and \nvalidate User ID preferences for uniqueness. The system must enforce mandatory consents for',
#  'validate User ID preferences for uniqueness. The system must enforce mandatory consents for \ncredit checks, data sharing, and privacy policy, with optional marketing consent. \n \nInitial Remittance',
#  'Initial Remittance \nTo ensure new accounts are funded promptly and to avoid prolonged zero-balance accounts,',
#  'To ensure new accounts are funded promptly and to avoid prolonged zero-balance accounts, \nthe system introduces the collection of Initial Remittance during account opening. This step',
#  'the system introduces the collection of Initial Remittance during account opening. This step \nintegrates with a payment gateway (EaseBuzz) and supports UPI, Debit Card, and NetBanking as',
#  'integrates with a payment gateway (EaseBuzz) and supports UPI, Debit Card, and NetBanking as \nmodes of payment.',
#  'modes of payment.  \nOnce the user agrees for “Initial Remittance”, the system will generate a payment link and QR',
#  'Once the user agrees for “Initial Remittance”, the system will generate a payment link and QR \nfor the user to make the payment. If the user opts to skip remittance, a reason must be',
#  'for the user to make the payment. If the user opts to skip remittance, a reason must be \nrecorded; blank or invalid skip reasons are not permitted',
#  'recorded; blank or invalid skip reasons are not permitted \nThe status of an initial remittance transaction will always fall into one of the following \ncategories:',
#  'categories:  \n• Success – Remittance completed; funds pending settlement into new account.  \n• Failure – Transaction failed; funds not received by the bank.',
#  '• Failure – Transaction failed; funds not received by the bank.  \n• Refunded – Remittance succeeded but funds were refunded due to account rejection or \ndelay.',
#  '• Refunded – Remittance succeeded but funds were refunded due to account rejection or \ndelay.  \n• Settled – Remittance succeeded; funds credited to the newly opened account.',
#  'delay.  \n• Settled – Remittance succeeded; funds credited to the newly opened account.  \n \nThe customer should be asked if they want to proceed to vKYC immediately or schedule it for a',
#  'The customer should be asked if they want to proceed to vKYC immediately or schedule it for a \nlater date/time.',
#  'Annex 1 – Declarations \n \n(This shall be displayed incase customer is “Non literate” selected in the customer educational',
#  '(This shall be displayed incase customer is “Non literate” selected in the customer educational \nqualification): Given that the customer is non literate, the requisite information furnished to the',
#  'bank/agent is filled in this application form and read out to the person. The signature/Thumb \nimpression of the applicants shall be deemed as a confirmation for reading out the contents of',
#  'impression of the applicants shall be deemed as a confirmation for reading out the contents of \nthe form and its correctness. [Descoped] \nImplement this: Before form signing, show this declaration',
#  'Implement this: Before form signing, show this declaration  \nBriefed the customer to provide accurate and complete information in the form and confirmed',
#  'Briefed the customer to provide accurate and complete information in the form and confirmed \nthat the information filled in fields like Income, Source of income/ Wealth, Occupation, business',
#  'that the information filled in fields like Income, Source of income/ Wealth, Occupation, business \nactivity, purpose of account opening and expected account turnover are once again verified with',
#  'activity, purpose of account opening and expected account turnover are once again verified with \nthe customer(s).If the customer falls into subcategory of the occupation, it has been invariably',
#  'the customer(s).If the customer falls into subcategory of the occupation, it has been invariably \nensured by the branch official/s. In the case of Enhanced Due Diligence, we confirm collection',
#  'ensured by the branch official/s. In the case of Enhanced Due Diligence, we confirm collection \nand recording of additional document/ information as per the guidance note on Account opening',
#  'and recording of additional document/ information as per the guidance note on Account opening \n& Customer Due Diligence.  \n \nAnnex 2 – Enhanced Due Diligence',
#  '& Customer Due Diligence.  \n \nAnnex 2 – Enhanced Due Diligence \nEnhanced Due Diligence (EDD) refers to additional measures undertaken beyond standard due',
#  'Enhanced Due Diligence (EDD) refers to additional measures undertaken beyond standard due \ndiligence, specifically for customers classified as high-risk. These measures also include',
#  'diligence, specifically for customers classified as high-risk. These measures also include \ncollecting further information from applicants identified as high-risk based on parameters such',
#  'collecting further information from applicants identified as high-risk based on parameters such \nas Occupation Code, Country Code, and High Net Worth Individual (HNI) status.',
#  'as Occupation Code, Country Code, and High Net Worth Individual (HNI) status.  \nThe list of questions is \ngiven below. Sl. No.  \nQuestion  Options / Input Format  \n1  Do you have any ongoing',
#  'given below. Sl. No.  \nQuestion  Options / Input Format  \n1  Do you have any ongoing \nentrepreneurial or \ncommercial ventures?  \ni) No, I am salaried ii) Yes, I \nam the sole owner iii) Yes, I',
#  'commercial ventures?  \ni) No, I am salaried ii) Yes, I \nam the sole owner iii) Yes, I \nco-own the business with \nothers  \n2  If you are running a business:  \n2.1  Briefly describe the nature',
#  'others  \n2  If you are running a business:  \n2.1  Briefly describe the nature \nof your business.  \n(Descriptive – one to two \nsentences)  \n2.2  Number of employees  ……………….(Enter numeric \nvalue only)',
#  '2.3 a)  Do you have inward and \noutward remittances \nrelated to your business \nactivity?  \ni) Yes ii) No  \n2.3 b)  If yes: i) What is the total \nvalue and volume of \nremittances per month? ii)',
#  '2.3 b)  If yes: i) What is the total \nvalue and volume of \nremittances per month? ii) \nWhat is the average ticket \nsize?  \ni) ……………….. (Value in \nnumbers)  \nii) ……………….. (Value in \nnumbers)',
#  'size?  \ni) ……………….. (Value in \nnumbers)  \nii) ……………….. (Value in \nnumbers)  \n2.4  Do you receive payments in \ncash for your business?  \ni)More than 50% in cash ii) \n100% in cash',
#  'cash for your business?  \ni)More than 50% in cash ii) \n100% in cash  \niii) Less than 50% in cash  \n2.5  Do you operate in multiple \nlocations?  \ni) Yes, within the country ii)',
#  '2.5  Do you operate in multiple \nlocations?  \ni) Yes, within the country ii) \nYes, in multiple countries \niii) No, only at a single \n(registered) location']
